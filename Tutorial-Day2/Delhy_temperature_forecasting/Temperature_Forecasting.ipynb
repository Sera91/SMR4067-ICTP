# %% [markdown]
# # **Climate Forecasting | LSTM | Time series**

# %% [markdown]
# <img height=1000 width=800 src="https://science.nasa.gov/wp-content/uploads/2023/12/climateprojection_768_80.jpg" />

# %% [markdown]
# ## **Libraries**

# %%
#import required libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
import math
from datetime import timedelta

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error , mean_absolute_error

import keras
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential
from keras.callbacks import EarlyStopping

# %% [markdown]
# ## **Preprocessing and Visualization**

# %%
df = pd.read_csv("/DailyDelhiClimateTrain.csv", parse_dates = True, index_col = "date")
df
# Out:
#              meantemp    humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...               ...         ...         ...           ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1462 entries, 2013-01-01 to 2017-01-01
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   meantemp      1462 non-null   float64
#  1   humidity      1462 non-null   float64
#  2   wind_speed    1462 non-null   float64
#  3   meanpressure  1462 non-null   float64
# dtypes: float64(4)
# memory usage: 57.1 KB

# %%
temp = go.Scatter(x=df.index, y=df['meantemp'], mode='lines', name='Temperature')

# Layout settings
layout = go.Layout(
    title='Mean Temperature',
    xaxis_title='date',
    yaxis_title='meantemp',
    legend=dict(x=0, y=1.0),
    margin=dict(l=80, r=80, t=40, b=40),
    height=500,
    width=1100,
)

# Combine the traces and layout
fig = go.Figure(data=temp, layout=layout)

# Display the plot
pio.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ea496c89-2632-4401-9d86-d5b15a1fcc1b" class="plotly-graph-div" style="height:500px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea496c89-2632-4401-9d86-d5b15a1fcc1b")) {                    Plotly.newPlot(                        "ea496c89-2632-4401-9d86-d5b15a1fcc1b",                        [{"mode":"lines","name":"Temperature","x":["2013-01-01T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-16T00:00:00","2013-02-17T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-23T00:00:00","2013-02-24T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-02T00:00:00","2013-03-03T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-09T00:00:00","2013-03-10T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-16T00:00:00","2013-03-17T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-23T00:00:00","2013-03-24T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-03-29T00:00:00","2013-03-30T00:00:00","2013-03-31T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-06T00:00:00","2013-04-07T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-13T00:00:00","2013-04-14T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-20T00:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-01T00:00:00","2013-06-02T00:00:00","2013-06-03T00:00:00","201 ...

# %%
humidity = go.Scatter(
    x=df.index,
    y=df['humidity'],
    mode='lines',
    name='Humidity',
    line=dict(color='red')
)

# Layout settings
layout = go.Layout(
    title='Humidity',
    xaxis_title='Date',
    yaxis_title='Humidity',
    legend=dict(x=0, y=1.0),
    margin=dict(l=80, r=80, t=40, b=40),
    height=500,
    width=1100,
)

# Combine the traces and layout
fig = go.Figure(data=[humidity], layout=layout)

# Display the plot
pio.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1224216e-3c67-48a5-a9ad-67ef14401b96" class="plotly-graph-div" style="height:500px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1224216e-3c67-48a5-a9ad-67ef14401b96")) {                    Plotly.newPlot(                        "1224216e-3c67-48a5-a9ad-67ef14401b96",                        [{"line":{"color":"red"},"mode":"lines","name":"Humidity","x":["2013-01-01T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-16T00:00:00","2013-02-17T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-23T00:00:00","2013-02-24T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-02T00:00:00","2013-03-03T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-09T00:00:00","2013-03-10T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-16T00:00:00","2013-03-17T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-23T00:00:00","2013-03-24T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-03-29T00:00:00","2013-03-30T00:00:00","2013-03-31T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-06T00:00:00","2013-04-07T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-13T00:00:00","2013-04-14T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-20T00:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-01T00:00:00","2013-06-02T00:00:00","2013- ...

# %%
wind_speed = go.Scatter(
    x=df.index,
    y=df['wind_speed'],
    mode='lines',
    name='Wind Speed',
    line=dict(color='purple')
)

# Layout settings
layout = go.Layout(
    title='Wind Speed',
    xaxis_title='Date',
    yaxis_title='Wind Speed',
    legend=dict(x=0, y=1.0),
    margin=dict(l=80, r=80, t=40, b=40),
    height=500,
    width=1100,
)

# Combine the traces and layout
fig = go.Figure(data=[wind_speed], layout=layout)

# Display the plot
pio.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="955981ce-31dc-406c-ae9f-858a3009ba85" class="plotly-graph-div" style="height:500px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("955981ce-31dc-406c-ae9f-858a3009ba85")) {                    Plotly.newPlot(                        "955981ce-31dc-406c-ae9f-858a3009ba85",                        [{"line":{"color":"purple"},"mode":"lines","name":"Wind Speed","x":["2013-01-01T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-16T00:00:00","2013-02-17T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-23T00:00:00","2013-02-24T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-02T00:00:00","2013-03-03T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-09T00:00:00","2013-03-10T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-16T00:00:00","2013-03-17T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-23T00:00:00","2013-03-24T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-03-29T00:00:00","2013-03-30T00:00:00","2013-03-31T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-06T00:00:00","2013-04-07T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-13T00:00:00","2013-04-14T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-20T00:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-01T00:00:00","2013-06-02T00:00:00"," ...

# %%
meanpressure = go.Scatter(
    x=df.index,
    y=df['meanpressure'],
    mode='lines',
    name='Mean Pressure',
    line=dict(color='orange')
)

# Layout settings
layout = go.Layout(
    title='Mean Pressure',
    xaxis_title='Date',
    yaxis_title='Mean Pressure',
    legend=dict(x=0, y=1.0),
    margin=dict(l=80, r=80, t=40, b=40),
    height=500,
    width=1100,
)

# Combine the traces and layout
fig = go.Figure(data=[meanpressure], layout=layout)

# Display the plot
pio.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3a057b4e-72f0-4120-a2bd-0e3e857c0e99" class="plotly-graph-div" style="height:500px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a057b4e-72f0-4120-a2bd-0e3e857c0e99")) {                    Plotly.newPlot(                        "3a057b4e-72f0-4120-a2bd-0e3e857c0e99",                        [{"line":{"color":"orange"},"mode":"lines","name":"Mean Pressure","x":["2013-01-01T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-16T00:00:00","2013-02-17T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-23T00:00:00","2013-02-24T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-02T00:00:00","2013-03-03T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-09T00:00:00","2013-03-10T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-16T00:00:00","2013-03-17T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-23T00:00:00","2013-03-24T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-03-29T00:00:00","2013-03-30T00:00:00","2013-03-31T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-06T00:00:00","2013-04-07T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-13T00:00:00","2013-04-14T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-20T00:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-01T00:00:00","2013-06-02T00:00:00 ...

# %%
dataset = df["meantemp"]
df2 = pd.DataFrame(dataset)
df2.values.shape
# Out:
# (1462, 1)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(np.array(df2).reshape(-1, 1))

# %%
train_size = int(len(data_scaled) * 0.75)
test_size = len(df2) - train_size
print(train_size, "/", test_size)
# Out:
# 1096 / 366

# %%
train_data = data_scaled[:train_size, 0:1]
train_data.shape
# Out:
# (1096, 1)

# %%
x_train = []
y_train = []

for i in range(60, len(train_data)):
               x_train.append(train_data[i-60:i, 0])
               y_train.append(train_data[i, 0])

x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
# Reshaping the input to 3D array [samples, time_steps, features].
x_train = np.reshape(x_train ,(x_train.shape[0], x_train.shape[1], 1))

# %% [markdown]
# ## **LSTM Model**

# %%
model = Sequential([
    LSTM(50, return_sequences=True,input_shape = (x_train.shape[1], 1) ),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(1)

])

model.compile(optimizer= "adamax", loss="mse", metrics=["mean_absolute_error"])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        29,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 42,465 (165.88 KB)
#  Trainable params: 42,465 (165.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
EarlyStopping = EarlyStopping(monitor="loss", patience=15, restore_best_weights=True)
history= model.fit(x_train, y_train, epochs=100, batch_size=32,callbacks = [EarlyStopping])
# Out:
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 88ms/step - loss: 0.1147 - mean_absolute_error: 0.2568
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0088 - mean_absolute_error: 0.0753
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0062 - mean_absolute_error: 0.0634
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0062 - mean_absolute_error: 0.0634
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0055 - mean_absolute_error: 0.0597
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0058 - mean_absolute_error: 0.0606
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0055 - mean_absolute_error: 0.0595
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0056 - mean_absolute_error: 0.0589
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.0054 - mean_absolute_error: 0.0581
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0054 - mean_absolute_error: 0.0580
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0051 - mean_absolute_error: 0.0558
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0053 - mean_absolute_error: 0.0566
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0053 - mean_absolute_error: 0.0575
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0051 - mean_absolute_error: 0.0561
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0051 - mean_absolute_error: 0.0561
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0048 - mean_absolute_error: 0.0547
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0046 - mean_absolute_error: 0.0534
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 0.0054 - mean_absolute_error: 0.0572
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0049 - mean_absolute_error: 0.0540
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0048 - mean_absolute_error: 0.0548
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0048 - mean_absolute_error: 0.0548
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0047 - mean_absolute_error: 0.0534
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0051 - mean_absolute_error: 0.0561
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.0050 - mean_absolute_error: 0.0557
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0043 - mean_absolute_error: 0.0510
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0043 - mean_absolute_error: 0.0503
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0048 - mean_absolute_error: 0.0550
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0042 - mean_absolute_error: 0.0503
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0045 - mean_absolute_error: 0.0524
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0045 - mean_absolute_error: 0.0526
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0049 - mean_absolute_error: 0.0547
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0047 - mean_absolute_error: 0.0533
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0048 - mean_absolute_error: 0.0540
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0046 - mean_absolute_error: 0.0532
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 0.0044 - mean_absolute_error: 0.0522
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0045 - mean_absolute_error: 0.0519
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0042 - mean_absolute_error: 0.0503
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 0.0041 - mean_absolute_error: 0.0495
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0041 - mean_absolute_error: 0.0502
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0044 - mean_absolute_error: 0.0520
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.0045 - mean_absolute_error: 0.0523
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0039 - mean_absolute_error: 0.0493
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0042 - mean_absolute_error: 0.0509
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0044 - mean_absolute_error: 0.0514
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0040 - mean_absolute_error: 0.0491
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0043 - mean_absolute_error: 0.0513
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0040 - mean_absolute_error: 0.0496
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0038 - mean_absolute_error: 0.0486
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0039 - mean_absolute_error: 0.0491
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0040 - mean_absolute_error: 0.0497
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0038 - mean_absolute_error: 0.0478
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - loss: 0.0041 - mean_absolute_error: 0.0504
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0038 - mean_absolute_error: 0.0487
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0040 - mean_absolute_error: 0.0496
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0035 - mean_absolute_error: 0.0453
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0040 - mean_absolute_error: 0.0505
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.0036 - mean_absolute_error: 0.0470
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0035 - mean_absolute_error: 0.0457
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0035 - mean_absolute_error: 0.0458
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0035 - mean_absolute_error: 0.0459
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0035 - mean_absolute_error: 0.0451
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0040 - mean_absolute_error: 0.0499
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0037 - mean_absolute_error: 0.0472
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 0.0035 - mean_absolute_error: 0.0459
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0033 - mean_absolute_error: 0.0453
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0034 - mean_absolute_error: 0.0454
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0033 - mean_absolute_error: 0.0452
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0032 - mean_absolute_error: 0.0438
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0035 - mean_absolute_error: 0.0458
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0031 - mean_absolute_error: 0.0425
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0041 - mean_absolute_error: 0.0501
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0034 - mean_absolute_error: 0.0450
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0037 - mean_absolute_error: 0.0473
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0030 - mean_absolute_error: 0.0425
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0028 - mean_absolute_error: 0.0414
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0031 - mean_absolute_error: 0.0432
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0026 - mean_absolute_error: 0.0403
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0030 - mean_absolute_error: 0.0425
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0031 - mean_absolute_error: 0.0432
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0027 - mean_absolute_error: 0.0405
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0026 - mean_absolute_error: 0.0390
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0029 - mean_absolute_error: 0.0412
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0031 - mean_absolute_error: 0.0435
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 0.0031 - mean_absolute_error: 0.0440
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.0033 - mean_absolute_error: 0.0440
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0028 - mean_absolute_error: 0.0407
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0027 - mean_absolute_error: 0.0411
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 0.0030 - mean_absolute_error: 0.0428
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0030 - mean_absolute_error: 0.0421
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0030 - mean_absolute_error: 0.0425
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0028 - mean_absolute_error: 0.0409
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0027 - mean_absolute_error: 0.0404
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0026 - mean_absolute_error: 0.0387
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0032 - mean_absolute_error: 0.0441
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0027 - mean_absolute_error: 0.0405
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0026 - mean_absolute_error: 0.0394
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0027 - mean_absolute_error: 0.0395
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0030 - mean_absolute_error: 0.0428
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0027 - mean_absolute_error: 0.0397
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0028 - mean_absolute_error: 0.0414

# %%
plt.figure(figsize=(10, 8))
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.title("Losses")
plt.xlabel("Mean squared error")
plt.ylabel("Mean absolute error")
plt.legend(["Mean squared error", "Mean absolute error"])
plt.show()

# %%
test_data = data_scaled[train_size - 60:, :]
x_test = []
y_test = []

for i in range(60, len(test_data)):
               x_test.append(test_data[i-60:i, 0])
               y_test.append(test_data[i, 0])

x_train = np.array(x_test)
y_train = np.array(y_test)

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_test.shape , y_test.shape
# Out:
# ((366, 60, 1), (366,))

# %%
predictions = model.predict(x_test)

predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# (366, 1)

# %%
y_test = scaler.inverse_transform([y_test])

RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# np.float64(0.42)

# %%
preds_acts = pd.DataFrame(data={'Predictions':predictions.flatten(), 'Actuals':y_test.flatten()})
preds_acts
# Out:
#      Predictions    Actuals
# 0      14.640602  14.000000
# 1      14.222291  14.375000
# 2      14.054895  15.750000
# 3      14.411362  15.833333
# 4      14.772609  17.375000
# ..           ...        ...
# 361    16.113874  17.217391
# 362    16.416777  15.238095
# 363    15.912825  14.095238
# 364    15.138213  15.052632
# 365    14.939725  10.000000
#
# [366 rows x 2 columns]

# %%
y_train_flattened = y_train.flatten()

# Create a DataFrame with 'train' as the column name
train = pd.DataFrame(data=y_train_flattened, columns=['train'])

# %%
plt.figure(figsize=(10, 8))
plt.plot(preds_acts["Predictions"])
plt.plot(preds_acts["Actuals"])
plt.title("Climate Forecasting")
plt.xlabel("Predictions")
plt.ylabel("Actuals")
plt.legend(["Predictions", "Actuals"])
plt.show()

# %% [markdown]
# ## **Temperature forecast for the next 50 days**

# %%
# Define the insert_end function
def insert_end(Xin, new_input):
    timestep = Xin.shape[1]  # Ensure timestep matches the input shape
    Xin[:, :-1, :] = Xin[:, 1:, :]  # Shift sequence
    Xin[:, -1, :] = new_input  # Insert new input at the end
    return Xin

# Forecast future values
future = 50
forcast = []
Xin = x_test[-1:, :, :]  # Initialize with the last input of the test set
time = []

for i in range(future):
    out = model.predict(Xin, batch_size=5)
    forcast.append(out[0])
    Xin = insert_end(Xin, out[0].reshape(1, 1, 1))  # Reshape for input
    time.append(pd.to_datetime(df.index[-1]) + timedelta(days=i))

# Convert forecasted output to numpy array and ensure correct shape
forcasted_output = np.array(forcast).reshape(-1, 1)  # Adjust shape as needed

# Apply inverse transformation (Ensure scaler is compatible with forecasted output)
forcasted_output = scaler.inverse_transform(forcasted_output)

# Convert forecasted output to DataFrame with appropriate column names
forcasted_output_df = pd.DataFrame(forcasted_output, columns=['meantemp'])  # Adjust columns if needed

# Convert `time` to DataFrame
date_df = pd.DataFrame(time, columns=['Date'])

# Concatenate date and forecasted output
df_result = pd.concat([date_df, forcasted_output_df], axis=1)

# Display the DataFrame
print(df_result.head())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
#         Date   meantemp
# 0 2017-01-01  14.939724
# 1 2017-01-02  14.816508
# 2 2017-01-03  14.724917
# 3 2017-01-04  14.646264
# 4 2017-01-05  14.571201

# %%
df_result.head(50)
# Out:
#          Date   meantemp
# 0  2017-01-01  14.939724
# 1  2017-01-02  14.816508
# 2  2017-01-03  14.724917
# 3  2017-01-04  14.646264
# 4  2017-01-05  14.571201
# 5  2017-01-06  14.497296
# 6  2017-01-07  14.425118
# 7  2017-01-08  14.350978
# 8  2017-01-09  14.274764
# 9  2017-01-10  14.198598
# 10 2017-01-11  14.123321
# 11 2017-01-12  14.048906
# 12 2017-01-13  13.977959
# 13 2017-01-14  13.909094
# 14 2017-01-15  13.842585
# 15 2017-01-16  13.779719
# 16 2017-01-17  13.721579
# 17 2017-01-18  13.668718
# 18 2017-01-19  13.619905
# 19 2017-01-20  13.579242
# 20 2017-01-21  13.543904
# 21 2017-01-22  13.516610
# 22 2017-01-23  13.496522
# 23 2017-01-24  13.481118
# 24 2017-01-25  13.475587
# 25 2017-01-26  13.478122
# 26 2017-01-27  13.486681
# 27 2017-01-28  13.500039
# 28 2017-01-29  13.518103
# 29 2017-01-30  13.538963
# 30 2017-01-31  13.564409
# 31 2017-02-01  13.593616
# 32 2017-02-02  13.630317
# 33 2017-02-03  13.668463
# 34 2017-02-04  13.710572
# 35 2017-02-05  13.756764
# 36 2017-02-06  13.806712
# 37 2017-02-07  13.858730
# 38 2017-02-08  13.918355
# 39 2017-02-09  13.977936
# 40 2017-02-10  14.046718
# 41 2017-02-11  14.119966
# 42 2017-02-12  14.196573
# 43 2017-02-13  14.276725
# 44 2017-02-14  14.360239
# 45 2017-02-15  14.443939
# 46 2017-02-16  14.532903
# 47 2017-02-17  14.622893
# 48 2017-02-18  14.718173
# 49 2017-02-19  14.819385

# %%
plt.figure(figsize=(20, 10))
plt.title('Next 30 Days')

plt.subplot(2, 2, 1)
plt.plot(df['meantemp'])
plt.plot(df_result.set_index('Date')[['meantemp']])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Temp' ,fontsize=18)

plt.tight_layout()
plt.show()
